# %%
from bs4 import BeautifulSoup 
import requests.exceptions 
from urllib.parse import urlsplit 
from urllib.parse import urlparse 
from collections import deque

# %%
urls = ["https://www.lawyersnjurists.com/articlecat/bank-and-financial-institutes/",
        "https://www.lawyersnjurists.com/articlecat/business/",
        "https://www.lawyersnjurists.com/articlecat/environment-and-geography/",
        "https://www.lawyersnjurists.com/articlecat/garments-and-textile/",
        "https://www.lawyersnjurists.com/articlecat/general-health-and-medical-science/",
        "https://www.lawyersnjurists.com/articlecat/hotel-and-tourism/",
        "https://www.lawyersnjurists.com/articlecat/human-resource-and-managment/",
        "https://www.lawyersnjurists.com/articlecat/it-and-software/",
        "https://www.lawyersnjurists.com/articlecat/law-and-ethics/",
        "https://www.lawyersnjurists.com/articlecat/real-estate/",
        "https://www.lawyersnjurists.com/articlecat/reports-on-ngo/",
        "https://www.lawyersnjurists.com/articlecat/science-and-technology/",
        "https://www.lawyersnjurists.com/articlecat/social-and-political-science/",
        "https://www.lawyersnjurists.com/articlecat/telecommunication/",
        "https://www.lawyersnjurists.com/articles-and-reports"]
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36'}
# url = "https://www.lawyersnjurists.com/"

# a queue of urls to be crawled next
new_urls = deque(urls)

# a set of urls that we have already processed
processed_urls = set()

# a set of domains inside the target website
local_urls = set()

# a set of domains outside the target website
foreign_urls = set()

# a set of broken urls
broken_urls = set()

# %%
# process urls one by one until we exhaust the queue
while len(new_urls):
    # move url from the queue to processed url set
    url = new_urls.popleft()
    processed_urls.add(url)
    # print the current url
    print("Processing %s" % url)
    
    # catching any broken web pages and add them to the broken_urls set for later use
    try: 
        response = requests.get(url,headers=headers)
    except(requests.exceptions.MissingSchema, requests.exceptions.ConnectionError, requests.exception.InvalidSchema):
        # add broken urls to it's own set, then continue
        broken_urls.add(url)
        continue
    print("Try-catch")
    # extract base urlto resolve relative links
    parts = urlsplit(url)
    base = "{0.netloc}".format(parts)
    strip_base = base.replace("www.","")
    base_url = "{0.scheme}://{0.netloc}".format(parts)
    path = url[:url.rfind('/')+1] if '/' in parts.path else url
    print("parsing")
    soup = BeautifulSoup(response.text, "lxml")
    for link in soup.find_all('a'):
        # extract link url from the anchor
        anchor = link.attrs["href"] if "href" in link.attrs else ''
        if anchor.startswith('/'):
            local_link = base_url + anchor
            local_urls.add(local_link)
        elif strip_base in anchor:
            local_urls.add(anchor)
        elif not anchor.startswith('http'):
            local_link = path + anchor
            local_urls.add(local_link)
        else: foreign_urls.add(anchor)
    print("Before appending local")
    for i in local_urls:
        if not i in new_urls and not i in processed_urls:
            new_urls.append(i)
# Out:
# Processing https://www.lawyersnjurists.com/articlecat/bank-and-financial-institutes/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/business/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/environment-and-geography/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/garments-and-textile/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/general-health-and-medical-science/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/hotel-and-tourism/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/human-resource-and-managment/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/it-and-software/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/law-and-ethics/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/real-estate/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/reports-on-ngo/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/science-and-technology/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/social-and-political-science/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/telecommunication/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articles-and-reports
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/contact-us/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/our-lawyers/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/the-remedies-available-to-a-muslim-women-to-recover-dower/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/quantum-of-dower-in-equity-of-redemption/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/bank-and-financial-institutes/page/68/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articles-and-reports/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/bank-reserves-part-1/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/unpaid-dower-under-muslim-law/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/what-is-psd2/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/conventions-treaties/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/our-services/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/character-of-dower/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/our-clients/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/widows-right-to-hold-possession-of-her-husbands-property-on-non-payment-of-dower-is-heritable-transferable-critically-analyse/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article
limited/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/credit-risk-management-crm-of-dhaka-bank-limited/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/special-powers-act-1974-2/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/customer-satisfaction-on-credit-card-services-provided-by-brac-bank/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/human-resource-management-of-dhaka-bank-ltd-2/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/reports-on-bangladeshi-fruits/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/commercial-banking-operations-with-special-reference-to-foreign-exchange-business-of-southeast-bank/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/practice-and-procedure-2/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/bank-and-financial-institutes/page/2/#
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/cost-volume-profit-analysis-2/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/legal-courses/#
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/#quote-carousel
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/distribution-channel-of-king-brand-cement-2/mailto:bgc@bdcom.com
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/distribution-channel-of-king-brand-cement-2/#
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/the-concept-of-dower-under-muslim-law/#
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/disclaimer/#
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/lawyer_ci/#
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/webmail
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/apply-career/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/inhouse-lawyer/#
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/definition-and-nature-of-dower/#
# Try-catch
# parsing
# Before appending local
# Processing http://www.lawyersnjurists.com/lawyer_ci/#
# Try-catch
# parsing
# Before appending local
# Processing http://www.lawyersnjurists.com:2095
# Try-catch
# parsing
# Before appending local
# Processing http://webmail.lawyersnjurists.com
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/business-environment/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/business-environment-of-cyber-cafe-and-its-impact-on-society-in-dhaka-city-a-sociological-study-----------business-environment-of-cyber-cafe---and-its-impact-on-society-in-dhaka-city----introduction-t/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/business/page/16/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/an-overview-of-the-performance-of-a-chartered-accountant-firm--a-case-study-on-a-matin--co/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/business/page/17/#
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/business-environment-2/#
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/dragon-fruit-and-its-benefits/#
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/berger-paint/#
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/pay-structure-and-benefit-policies-of-biman-bangladesh-airlines/#
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/community-exchange-system/#
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/analysis-report-on-bio-diesel-from-algae/#
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/analysis-report-on-bio-diesel-from-algae/file:///D:/papon%20share%20data/done%20for%20final%20loading/Analisis.xlsx
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/environment-and-geography/page/5/#
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/study-urban-heat-island-effect-dhaka-city/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/forest-importance-environment/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/geological--field--report--based-on-the-fieldwork-along-jaintlapur-and-adjoining-areas-of-sylhet/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/environmental-impact-assessment-jamuna-bridge-construction-mitigation-measures/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/articlecat/environment-and-geography/page/4/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/marine-pollution/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/green-house/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/articles-about-lalbagh-kella/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/consumer-preferences-expectations-upcoming-eco-resort-sundarbans/
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/reaction-to-crime-has-been-different-at-different-stages-of-human-civilization-and-even-different-in-various-societies/#_ftn5
# Try-catch
# parsing
# Before appending local
# Processing https://www.lawyersnjurists.com/article/reaction-to-crime-has-been-different-at-different-stages-of-human-civilization-and-even-different-in-various-societies/#_ftnref1
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# c:\program files\python39\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# c:\program files\python39\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# c:\program files\python39\lib\http\client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# c:\program files\python39\lib\socket.py in readinto(self, b)
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#
# c:\program files\python39\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# c:\program files\python39\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ConnectionAbortedError: [WinError 10053] An established connection was aborted by the software in your host machine
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     530             if read is False or not self._is_method_retryable(method):
# --> 531                 raise six.reraise(type(error), error, _stacktrace)
#     532             elif read is not None:
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# c:\program files\python39\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# c:\program files\python39\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# c:\program files\python39\lib\http\client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# c:\program files\python39\lib\socket.py in readinto(self, b)
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#
# c:\program files\python39\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# c:\program files\python39\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ProtocolError: ('Connection aborted.', ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-6-490764c5dc9f> in <module>
#      10     try:
# ---> 11         response = requests.get(url,headers=headers)
#      12     except(requests.exceptions.MissingSchema, requests.exceptions.ConnectionError, requests.exception.InvalidSchema):
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\api.py in get(url, params, **kwargs)
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\api.py in request(method, url, **kwargs)
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#
# ~\AppData\Roaming\Python\Python39\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#
# ConnectionError: ('Connection aborted.', ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-490764c5dc9f> in <module>
#      10     try:
#      11         response = requests.get(url,headers=headers)
# ---> 12     except(requests.exceptions.MissingSchema, requests.exceptions.ConnectionError, requests.exception.InvalidSchema):
#      13         # add broken urls to it's own set, then continue
#      14         broken_urls.add(url)
#
# AttributeError: module 'requests' has no attribute 'exception'
